# %% [markdown]
#  ## Drug Discovery
#
#  In this Project we will explore the drug discovery project for HIV using the ChEMBL Database.
# ## So what is the ChEMBL data base?
#    <li> This is a data base that combines the chemical, biological and genomic data, allowing for a link between the target drug or illness. </li>
#    <li> This is a great resource for many bioinformaticians because it contains 12 million bioactivity data set extracted from 51,000 publications </li>

# %% [markdown]
# Here are the basic steps to get the ChEMBL database on python.
# 1. Install the ChEMBL Library

# %%
pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.10.8)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (2.0.4)
# Requirement already satisfied: requests>=2.18.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Requirement already satisfied: attrs<22.0,>=21.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /Users/kashishbhatt/Library/Python/3.11/lib/python/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now we need to import the libraries to visual the data. Here the libraries we will use are pandas and new_client.
# <li> pandas ~ this is an open source library that useful for data analysis and data manipulation.  This is one of the most commonly used tools in data science and Machine Learning. And some key features include: </li>
#         <li> Data Structures:  There are usually two main data structures: Dataframe and the series. The DataFrame is more like a spreadsheet or sort of like an SQL table while the series is one dimensional like a column, its an array. </li>
#         <li> Data Manipulation: As the name suggest, pandas library has the ability to manipulate data. </li>
#         <li> Data Cleaning: This is good for cleaning data like fixing missing data, duplicate data and handling inconsistencies </li>
#         <li> Data Analysis: Again like the name suggests the data analysis is a major feature in the pandas library. This can include: calculating descriptive statistics, generate summary reports, and visualizing data </li>
#         <li> Time Series Analysis: Pandas is a great tool to use when we are dealing with features like date and time. </li>
#         <li> Reading/Writing: It supports writing and reading data to and from different formats of files like SQl, CSV, Excel, JASON, etc. </li>
#         <li> Integration: Pandas can integrate with other python libraries like Numpy and scikit-learn (which is a library used for machine learning) </li>
#
# The second library we will use is this one:
# <li> chembl_webresource_client: this is a library that will help us connect with the ChEMBL database, and we will import and using this library we will import new_client. </li>
# <li> new_client: This is a module or a class named new_client inside the hembl_webresource_client </li>

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Here we will search for Target Proteins

# %%
target = new_client.target
target_query = target.search('HIV')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P51681', 'xref_name': None, 'xre...
# 5  [{'xref_id': 'P15822', 'xref_name': None, 'xre...
# 6  [{'xref_id': 'Q92993', 'xref_name': None, 'xre...
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                        organism  \
# 0  Human immunodeficiency virus
# 1                 HIV-1 M:B_Lai
# 2                  Homo sapiens
# 3                  Homo sapiens
# 4                  Homo sapiens
# 5                  Homo sapiens
# 6                  Homo sapiens
# 7                  Homo sapiens
# 8                  Homo sapiens
# 9                  Homo sapiens
#
#                                            pref_name  score  \
# 0                                       HIV protease   19.0
# 1                                      HIV-1 M:B_Lai   15.0
# 2                        Transcription factor HIVEP2   12.0
# 3                        Ubiquitin thioesterase OTU1   12.0
# 4                      C-C chemokine receptor type 5   11.0
# 5  Human immunodeficiency virus type I enhancer-b...    9.0
# 6                     Histone acetyltransferase KAT5    9.0
# 7                    CCR5/mu opioid receptor complex    9.0
# 8   Zinc finger and BTB domain-containing protein 7A    7.0
# 9                                       80S Ribosome    0.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL3638323
# 1               False     CHEMBL612775
# 2               False    CHEMBL4523214
# 3               False    CHEMBL4630833
# 4               False        CHEMBL274
# 5               False       CHEMBL2909
# 6               False       CHEMBL5750
# 7               False    CHEMBL3301384
# 8               False    CHEMBL5069375
# 9               False    CHEMBL3987582
#
#                                    target_components  \
# 0  [{'accession': 'Q9YQ30', 'component_descriptio...
# 1                                                 []
# 2  [{'accession': 'P31629', 'component_descriptio...
# 3  [{'accession': 'Q5VVQ6', 'component_descriptio...
# 4  [{'accession': 'P51681', 'component_descriptio...
# 5  [{'accession': 'P15822', 'component_descriptio...
# 6  [{'accession': 'Q92993', 'component_descriptio...
# 7  [{'accession': 'P51681', 'component_descriptio...
# 8  [{'accession': 'O95365', 'component_descriptio...
# 9  [{'accession': 'P08865', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   12721
# 1                      ORGANISM  290579
# 2                SINGLE PROTEIN    9606
# 3                SINGLE PROTEIN    9606
# 4                SINGLE PROTEIN    9606
# 5                SINGLE PROTEIN    9606
# 6                SINGLE PROTEIN    9606
# 7               PROTEIN COMPLEX    9606
# 8                SINGLE PROTEIN    9606
# 9  PROTEIN NUCLEIC-ACID COMPLEX    9606

# %% [markdown]
# Now lets say we want to select a perticular entry for us lets pretend that its Human immunodeficiency virus type I enhancer-b. So to go about selecting this entry we would use this code (notice we used the index of 6 instead of 5 because the table started at 0):

# %%
select_target = targets.target_chembl_id[6]
select_target
# Out:
# 'CHEMBL5750'

# %% [markdown]
# The ID 'CHEMBL5750' is the bioactivity of data for the HIV ype I enhancer-b, this is the unique identification of the target in the ChEMBL data.

# %% [markdown]
# Now if we want to only obtain the bioactivity data for HIV type I enhancer-b, meaning we only care about the the effect of that perticular tissue, we will use this code:

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=select_target).filter(target_type = "SINGLE PROTEIN")
df = pd.DataFrame.from_dict(res)
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2490443                  []
# 1        None             None      2490445                  []
# 2        None             None      2490449                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1029727  Inhibition of TIP60 in human HeLa cell extract...
# 1   CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 2   CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism                target_pref_name target_tax_id text_value  \
# 0    Homo sapiens  Histone acetyltransferase KAT5          9606       None
# 1    Homo sapiens  Histone acetyltransferase KAT5          9606       None
# 2    Homo sapiens  Histone acetyltransferase KAT5          9606       None
#
#    toid  type units    uo_units upper_value   value
# 0  None  IC50    uM  UO_0000065        None     9.0
# 1  None  IC50    uM  UO_0000065        None  143.35
# 2  None  IC50    uM  UO_0000065        None   111.7
#
# [3 rows x 46 columns]

# %% [markdown]
# Here in this code we did a few things, we created a new variable named activity, which is a new instance and calls the activity attribute of the new client object. This allows us to have an object that we can use to get various operations related to activities recorded in the data base. We also filtered out what we wanted with the first instance only asking for elect_target (which we previous made a variable for) and the second filter is the target_type found on the data base and exactly what target we want. The command df.head(3) gives us the 3 top results in the dataframe.

# %% [markdown]
# # Saving the data in to a CSV file

# %%
df.to_csv('bioactivity_data_HIV.csv', index=False)

# %% [markdown]
# # Handling missing data
# There maybe some data that is missing in our database so to find lets say missing data for the value we would use this code:

# %%
df2 = df[df.value.notna()]
df2
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 79                                               None             None
# 80                                               None             None
# 81                                               None             None
# 82  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 83                                               None             None
#
#     activity_id                                activity_properties  \
# 0       2490443                                                 []
# 1       2490445                                                 []
# 2       2490449                                                 []
# 3       2490453                                                 []
# 4       2490457                                                 []
# ..          ...                                                ...
# 79     24342485                                                 []
# 80     24342486                                                 []
# 81     24849004  [{'comments': None, 'relation': '=', 'result_f...
# 82     24849005  [{'comments': None, 'relation': '=', 'result_f...
# 83     24957706  [{'comments': None, 'relation': None, 'result_...
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1029727  Inhibition of TIP60 in human HeLa cell extract...
# 1    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 2    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 3    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 4    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# ..             ...                                                ...
# 79   CHEMBL5029729               Inhibition of TIP60 (unknown origin)
# 80   CHEMBL5029729               Inhibition of TIP60 (unknown origin)
# 81   CHEMBL5147377  Inhibition of GST tagged human TIP60 expressed...
# 82   CHEMBL5147377  Inhibition of GST tagged human TIP60 expressed...
# 83   CHEMBL5214072  Selectivity interaction (HAT panel) EUB0000329...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 79          B                    None                   None  BAO_0000190
# 80          B                    None                   None  BAO_0000190
# 81          B                    None                   None  BAO_0000190
# 82          B                    None                   None  BAO_0000190
# 83          B                    None                   None  BAO_0000190
#
#     ... target_organism                target_pref_name target_tax_id  \
# 0   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 1   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 2   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 3   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 4   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# ..  ...             ...                             ...           ...
# 79  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 80  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 81  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 82  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 83  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
#
#    text_value  toid  type units    uo_units upper_value   value
# 0        None  None  IC50    uM  UO_0000065        None     9.0
# 1        None  None  IC50    uM  UO_0000065        None  143.35
# 2        None  None  IC50    uM  UO_0000065        None   111.7
# 3        None  None  IC50    uM  UO_0000065        None   25.87
# 4        None  None  IC50    uM  UO_0000065        None    17.3
# ..        ...   ...   ...   ...         ...         ...     ...
# 79       None  None  IC50    uM  UO_0000065        None    50.0
# 80       None  None  IC50    uM  UO_0000065        None    50.0
# 81       None  None  IC50    uM  UO_0000065        None    50.0
# 82       None  None  IC50    uM  UO_0000065        None    37.2
# 83       None  None  IC50    µM        None        None     8.7
#
# [69 rows x 46 columns]

# %% [markdown]
# So Here the code df[df.value.notna()] is bassically saying we need to create a dataframe using the old dataframe (df) which we initially created and drop it. Here there seems to be no missing data.

# %% [markdown]
# # Preprocessing the Data
# Here we will lable whether these compounds are active or inactive. First what we will do is create another target, using type and then we will lable them as active and inactive depending on the value.

# %%
# Here we will create another target: 
select_target = targets.target_chembl_id[6]
act = new_client.activity
res = act.filter(target_chembl_id=select_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# 5                                                None             None
# 6                                                None             None
# 7                                                None             None
# 8                                                None             None
# 9                                                None             None
# 10                                               None             None
# 11                                               None             None
# 12                                               None             None
# 13                                               None             None
# 14                                               None             None
# 15                                               None             None
# 16                                               None             None
# 17                                               None             None
# 18                                               None             None
# 19                                               None             None
# 20                                               None             None
# 21                                               None             None
# 22                                               None             None
# 23                                               None             None
# 24  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 25                                               None             None
#
#     activity_id                                activity_properties  \
# 0       2490443                                                 []
# 1       2490445                                                 []
# 2       2490449                                                 []
# 3       2490453                                                 []
# 4       2490457                                                 []
# 5       2490461                                                 []
# 6       2490465                                                 []
# 7       2490469                                                 []
# 8       2490473                                                 []
# 9       2490477                                                 []
# 10      2490483                                                 []
# 11      7994840                                                 []
# 12      7994841                                                 []
# 13     16507849                                                 []
# 14     16507889                                                 []
# 15     16507891                                                 []
# 16     18777027                                                 []
# 17     19272189                                                 []
# 18     19272232                                                 []
# 19     19272235                                                 []
# 20     19272250                                                 []
# 21     24342485                                                 []
# 22     24342486                                                 []
# 23     24849004  [{'comments': None, 'relation': '=', 'result_f...
# 24     24849005  [{'comments': None, 'relation': '=', 'result_f...
# 25     24957706  [{'comments': None, 'relation': None, 'result_...
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1029727  Inhibition of TIP60 in human HeLa cell extract...
# 1    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 2    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 3    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 4    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 5    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 6    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 7    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 8    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 9    CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 10   CHEMBL1025546  Inhibition of recombinant Tip60 (1-513) expres...
# 11   CHEMBL1938102  Inhibition of human recombinant His-tagged Tip...
# 12   CHEMBL1938102  Inhibition of human recombinant His-tagged Tip...
# 13   CHEMBL3778097  Inhibition of recombinant TIP60 (unknown origi...
# 14   CHEMBL3779611  Inhibition of full length TIP60 (unknown origi...
# 15   CHEMBL3779612  Inhibition of recombinant N-terminal His-tagge...
# 16   CHEMBL4269221               Inhibition of Tip60 (unknown origin)
# 17   CHEMBL4407057  Displacement of [3H]-acetyl-CoA from recombina...
# 18   CHEMBL4407075               Inhibition of Tip60 (unknown origin)
# 19   CHEMBL4407078  Inhibition of Tip60 (unknown origin) using [3H...
# 20   CHEMBL4407093                Inhibition of KAT5 (unknown origin)
# 21   CHEMBL5029729               Inhibition of TIP60 (unknown origin)
# 22   CHEMBL5029729               Inhibition of TIP60 (unknown origin)
# 23   CHEMBL5147377  Inhibition of GST tagged human TIP60 expressed...
# 24   CHEMBL5147377  Inhibition of GST tagged human TIP60 expressed...
# 25   CHEMBL5214072  Selectivity interaction (HAT panel) EUB0000329...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
# 19          B                    None                   None  BAO_0000190
# 20          B                    None                   None  BAO_0000190
# 21          B                    None                   None  BAO_0000190
# 22          B                    None                   None  BAO_0000190
# 23          B                    None                   None  BAO_0000190
# 24          B                    None                   None  BAO_0000190
# 25          B                    None                   None  BAO_0000190
#
#     ... target_organism                target_pref_name target_tax_id  \
# 0   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 1   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 2   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 3   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 4   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 5   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 6   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 7   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 8   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 9   ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 10  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 11  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 12  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 13  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 14  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 15  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 16  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 17  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 18  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 19  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 20  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 21  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 22  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 23  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 24  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
# 25  ...    Homo sapiens  Histone acetyltransferase KAT5          9606
#
#    text_value  toid  type units    uo_units upper_value   value
# 0        None  None  IC50    uM  UO_0000065        None     9.0
# 1        None  None  IC50    uM  UO_0000065        None  143.35
# 2        None  None  IC50    uM  UO_0000065        None   111.7
# 3        None  None  IC50    uM  UO_0000065        None   25.87
# 4        None  None  IC50    uM  UO_0000065        None    17.3
# 5        None  None  IC50    uM  UO_0000065        None   20.91
# 6        None  None  IC50    uM  UO_0000065        None   79.62
# 7        None  None  IC50    uM  UO_0000065        None   29.75
# 8        None  None  IC50    uM  UO_0000065        None  374.59
# 9        None  None  IC50    uM  UO_0000065        None   200.0
# 10       None  None  IC50    uM  UO_0000065        None   82.27
# 11       None  None  IC50    uM  UO_0000065        None    64.0
# 12       None  None  IC50    uM  UO_0000065        None    74.0
# 13       None  None  IC50    uM  UO_0000065        None    70.0
# 14       None  None  IC50    uM  UO_0000065        None   149.0
# 15       None  None  IC50    uM  UO_0000065        None     2.0
# 16       None  None  IC50    uM  UO_0000065        None    64.0
# 17       None  None  IC50    uM  UO_0000065        None     2.0
# 18       None  None  IC50    uM  UO_0000065        None    70.0
# 19       None  None  IC50    uM  UO_0000065        None     2.0
# 20       None  None  IC50    uM  UO_0000065        None   200.0
# 21       None  None  IC50    uM  UO_0000065        None    50.0
# 22       None  None  IC50    uM  UO_0000065        None    50.0
# 23       None  None  IC50    uM  UO_0000065        None    50.0
# 24       None  None  IC50    uM  UO_0000065        None    37.2
# 25       None  None  IC50    µM        None        None     8.7
#
# [26 rows x 46 columns]

# %% [markdown]
# Now we create the lables that will define whether the compounds are active or inactive. In our process the compounds that have a value of less than 150 will be active and the compounds with value of greater than 200 will be inactive. Values between 150 to 200 will be intermediate.

# %%
bioactivity_class = []
for i in df.value:
  if float(i) >= 200:
    bioactivity_class.append("inactive")
  elif float(i) <= 150:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# Now we want to combine the 4 columns (assay_chembl_id, target_organism, target_pref_name, and Value) and bioactivity_class into a DataFrame. Remember the bioactivity_class is a df we created. The command pd.concat combines the dfs.

# %%
selection = ['assay_chembl_id','target_organism', 'target_pref_name', 'value']
df3 = df2[selection]
df3
# Out:
#    assay_chembl_id target_organism                target_pref_name   value
# 0    CHEMBL1029727    Homo sapiens  Histone acetyltransferase KAT5     9.0
# 1    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5  143.35
# 2    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   111.7
# 3    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   25.87
# 4    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5    17.3
# ..             ...             ...                             ...     ...
# 79   CHEMBL5029729    Homo sapiens  Histone acetyltransferase KAT5    50.0
# 80   CHEMBL5029729    Homo sapiens  Histone acetyltransferase KAT5    50.0
# 81   CHEMBL5147377    Homo sapiens  Histone acetyltransferase KAT5    50.0
# 82   CHEMBL5147377    Homo sapiens  Histone acetyltransferase KAT5    37.2
# 83   CHEMBL5214072    Homo sapiens  Histone acetyltransferase KAT5     8.7
#
# [69 rows x 4 columns]

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#    assay_chembl_id target_organism                target_pref_name   value  \
# 0    CHEMBL1029727    Homo sapiens  Histone acetyltransferase KAT5     9.0
# 1    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5  143.35
# 2    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   111.7
# 3    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   25.87
# 4    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5    17.3
# ..             ...             ...                             ...     ...
# 81   CHEMBL5147377    Homo sapiens  Histone acetyltransferase KAT5    50.0
# 82   CHEMBL5147377    Homo sapiens  Histone acetyltransferase KAT5    37.2
# 83   CHEMBL5214072    Homo sapiens  Histone acetyltransferase KAT5     8.7
# 12             NaN             NaN                             NaN     NaN
# 14             NaN             NaN                             NaN     NaN
#
#    bioactivity_class
# 0             active
# 1             active
# 2             active
# 3             active
# 4             active
# ..               ...
# 81               NaN
# 82               NaN
# 83               NaN
# 12            active
# 14            active
#
# [71 rows x 5 columns]

# %% [markdown]
# Notice there are some missing values in the bioactivity column as well as other coloumns so lets see if we can fix that:

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4 = df4.dropna(subset=['bioactivity_class', "target_pref_name", "target_organism", "assay_chembl_id"])
df4
# Out:
#    assay_chembl_id target_organism                target_pref_name   value  \
# 0    CHEMBL1029727    Homo sapiens  Histone acetyltransferase KAT5     9.0
# 1    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5  143.35
# 2    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   111.7
# 3    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   25.87
# 4    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5    17.3
# 5    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   20.91
# 6    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   79.62
# 7    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   29.75
# 8    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5  374.59
# 9    CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   200.0
# 10   CHEMBL1025546    Homo sapiens  Histone acetyltransferase KAT5   82.27
# 11   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    76.0
# 13   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    76.0
# 15   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    76.0
# 16   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    76.0
# 17   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    76.0
# 18   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    76.0
# 19   CHEMBL1938099    Homo sapiens  Histone acetyltransferase KAT5    88.0
# 20   CHEMBL1938102    Homo sapiens  Histone acetyltransferase KAT5    64.0
# 21   CHEMBL1938102    Homo sapiens  Histone acetyltransferase KAT5    74.0
# 22   CHEMBL1938107    Homo sapiens  Histone acetyltransferase KAT5    54.0
# 23   CHEMBL1938107    Homo sapiens  Histone acetyltransferase KAT5   572.0
# 24   CHEMBL1938108    Homo sapiens  Histone acetyltransferase KAT5   660.0
# 25   CHEMBL1938108    Homo sapiens  Histone acetyltransferase KAT5    78.0
#
#    bioactivity_class
# 0             active
# 1             active
# 2             active
# 3             active
# 4             active
# 5             active
# 6             active
# 7             active
# 8           inactive
# 9           inactive
# 10            active
# 11            active
# 13            active
# 15            active
# 16            active
# 17            active
# 18            active
# 19            active
# 20          inactive
# 21            active
# 22            active
# 23            active
# 24            active
# 25            active

# %% [markdown]
# Now we save this to a CSV file format and we are good to go!

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)
